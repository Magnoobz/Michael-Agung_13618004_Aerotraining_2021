# %% [markdown]
# # Transonic Airfoil Aerodynamic Coefficients Prediction using Artificial Neural Network

# %% [markdown]
# ##Fill in your answer in "isi jawaban anda!"

# %% [markdown]
# In this notebook, an artificial neural network being modeled to predict the aerodynamic coefficients of an airfoil that flies at a nominal condition of __Mach Number M = 0.729__ where the data of varying M and __angle of attack α__ results in various __lift coefficient Cl__, __drag coefficient Cd__ and the pressure coefficient at the center of the upper surface of the airfoil __Cp__ using _Tensorflow and Keras_.
#
# The data were taken from the following reference: Pramudita Satria Palar, Lavi Rizki Zuhal, and Koji Shimoyama."Gaussian Process Surrogate Model with Composite Kernel Learning for Engineering Design." _AIAA Journal_ 58, no. 4 (2020):1864-1880.
#
# _Notebook made to explore simple Artificial Neural Network, Rafael S_

# %% [markdown]
# ### Importing required packages

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv('transonic_airfoil_data_set.csv').drop(columns = 'No')
df
# Out:
#             M       AoA        Cl        Cd        Cp
# 0    0.727928  2.449037  0.740129  0.013330 -0.911550
# 1    0.736393  2.389265  0.736667  0.015423 -1.218775
# 2    0.731969  2.251332  0.709717  0.013156 -1.122496
# 3    0.735015  2.388274  0.736197  0.014977 -1.214580
# 4    0.725872  2.448004  0.737060  0.012857 -0.697603
# ..        ...       ...       ...       ...       ...
# 961  0.735045  2.165183  0.698091  0.013423 -1.164278
# 962  0.726631  2.204177  0.693080  0.011845 -0.626338
# 963  0.727602  2.113649  0.678026  0.011613 -0.634598
# 964  0.738150  2.251622  0.715140  0.014969 -1.198659
# 965  0.728880  2.491825  0.749115  0.013877 -1.037020
#
# [966 rows x 5 columns]

# %% [markdown]
# ### Data Plot

# %% [markdown]
# Plotting the data to have a better visualization of our data distribution and linearity.

# %% [markdown]
# #### Lift Coefficient Cl Plot

# %%
figcl = plt.figure(figsize = [6,6])
clplot = Axes3D(figcl)
clplot.scatter(df['M'], df['AoA'], df['Cl'])
clplot.set_xlabel('Mach Number')
clplot.set_ylabel('Angle of Attack (degree)')
clplot.set_zlabel('Cl')
plt.show()

plt.scatter(df['M'], df['Cl'], alpha = 0.3)
plt.xlabel('Mach Number')
plt.ylabel('Cl')
plt.title('Cl vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cl'], alpha = 0.3)
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cl')
plt.title('Cl vs AoA')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_5516/603111466.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   clplot = Axes3D(figcl)

# %% [markdown]
# #### Drag Coefficient Cd Plot

# %%
figcd = plt.figure(figsize = [6,6])
cdplot = Axes3D(figcd)
cdplot.scatter(df['M'], df['AoA'], df['Cd'], c = 'r', alpha = 0.3)
cdplot.set_xlabel('Mach Number')
cdplot.set_ylabel('Angle of Attack (degree)')
cdplot.set_zlabel('Cd')
plt.show()

plt.scatter(df['M'], df['Cd'], alpha = 0.2, c = 'r')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cd'], alpha = 0.2, c = 'r')
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_5516/4091091764.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   cdplot = Axes3D(figcd)

# %% [markdown]
# #### Pressure Coefficient Cp Plot

# %%
figcp = plt.figure(figsize = [6,6])
cpplot = Axes3D(figcp)
cpplot.scatter(df['M'], df['AoA'], df['Cp'], c = 'g')
cpplot.set_xlabel('Mach Number')
cpplot.set_ylabel('Angle of Attack (degree)')
cpplot.set_zlabel('Cp')
plt.show()

plt.scatter(df['M'], df['Cp'], alpha = 0.3, c = 'g')
plt.xlabel('Mach Number')
plt.ylabel('Cp')
plt.title('Cp vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cp'], alpha = 0.3, c = 'g')
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cp')
plt.title('Cp vs AoA')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_5516/1610619952.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   cpplot = Axes3D(figcp)

# %% [markdown]
# ### Correlation Coefficient

# %% [markdown]
# Checking the Pearson's correlation coefficient to measure the statistical relationship, or association, between the variables.

# %%
# df_heatmap = sns.heatmap(df.corr(), annot = True, cmap = 'coolwarm')

# %% [markdown]
# ### Input and Output Data
# Defining the input data and the output data.

# %%
X = df.loc[:, ["M", "AoA"]]
y = df.loc[:, ["Cl", "Cd", "Cp"]]

# %%
# X #Input Data

# %%
# y #Output Data

# %% [markdown]
# ### Dataset Split (Training and Validation Data)
# Splitting the dataset by random and evenly distributed for the training and validation dataset.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 29)

# %% [markdown]
# Plotting to visualize the dataset split result.

# %%
# Creating figure
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(X_train['M'], X_train['AoA'], y_train['Cl'], color = "green", alpha=0.3, label='Train Data')
visual_split.scatter3D(X_test['M'], X_test['AoA'], y_test['Cl'], color = "red",alpha=0.5, label='Test Data')
plt.title("Train and Test Dataset")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

# %% [markdown]
# ## Normalizing The Data

# %% [markdown]
# Normalization ensures that the magnitude of the values that a feature assumes are more or less the same.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scalery = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

y_train = scalery.fit_transform(y_train)
y_test = scalery.transform(y_test)

# %% [markdown]
# ## Modeling The Artificial Neural Network

# %% [markdown]
# The activation function for the hidden layer of the network is using the Rectified Linear Unit (ReLU) function as it is a simple, fast and observed to converge much more quickly and reliably.
#
# The Dropout algorithm is commented out as it doesn't provide improvements after a few trainings, and early stopping method is being used instead to avoid overfitting our neural network to the dataset.
#
# The optimizer is the adam optimizer as it provides an adaptive learning rate to optimize better.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
NNmodel = Sequential()

NNmodel.add(Dense(30,activation='relu')) #Hidden Layer
# NNmodel.add(Dropout(0.2))
NNmodel.add(Dense(20,activation='relu')) #Hidden Layer
# NNmodel.add(Dropout(0.2))
NNmodel.add(Dense(30,activation='relu')) #Hidden Layer
# NNmodel.add(Dropout(0.2))

NNmodel.add(Dense(units = 3,activation='linear')) #Output Layer

NNmodel.compile(loss='mse', optimizer='adam')

# %% [markdown]
# ### Early Stopping

# %% [markdown]
# To avoid overfitting during the training of the neural network, early stopping method is being added. Early stopping is a form of regularization used to avoid overfitting when training a learner with an iterative method.

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

# %% [markdown]
# ### Training The Artificial Neural Network

# %%
NNmodel.fit(x=X_train, y=y_train, epochs=1000, validation_data=(X_test,y_test), callbacks=[early_stop])
# Out:
# Epoch 1/1000
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2097 - val_loss: 0.1257
# Epoch 2/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0761 - val_loss: 0.0568
# Epoch 3/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0532 - val_loss: 0.0470
# Epoch 4/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0441 - val_loss: 0.0388
# Epoch 5/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0374 - val_loss: 0.0327
# Epoch 6/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0304 - val_loss: 0.0248
# Epoch 7/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0211 - val_loss: 0.0172
# Epoch 8/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0106
# Epoch 9/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0078
# Epoch 10/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0070
# Epoch 11/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 12/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 13/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 14/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 15/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 16/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 17/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 18/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 19/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 20/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 21/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 22/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 23/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 24/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 25/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 26/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 27/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 28/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 29/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 9.6036e-04 - val_loss: 9.8118e-04
# Epoch 30/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 8.8440e-04 - val_loss: 8.9732e-04
# Epoch 31/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 8.1910e-04 - val_loss: 8.3330e-04
# Epoch 32/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 7.5127e-04 - val_loss: 7.7718e-04
# Epoch 33/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.9718e-04 - val_loss: 7.5729e-04
# Epoch 34/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.7329e-04 - val_loss: 6.6690e-04
# Epoch 35/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.3617e-04 - val_loss: 6.3261e-04
# Epoch 36/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.9286e-04 - val_loss: 6.3658e-04
# Epoch 37/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.4049e-04 - val_loss: 5.5452e-04
# Epoch 38/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.0972e-04 - val_loss: 5.3592e-04
# Epoch 39/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.7175e-04 - val_loss: 4.9059e-04
# Epoch 40/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.3620e-04 - val_loss: 4.6805e-04
# Epoch 41/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.0948e-04 - val_loss: 4.5661e-04
# Epoch 42/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.8276e-04 - val_loss: 4.0490e-04
# Epoch 43/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.5942e-04 - val_loss: 3.9501e-04
# Epoch 44/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.4099e-04 - val_loss: 3.7953e-04
# Epoch 45/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.1500e-04 - val_loss: 3.3491e-04
# Epoch 46/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.9097e-04 - val_loss: 3.1713e-04
# Epoch 47/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6902e-04 - val_loss: 2.9635e-04
# Epoch 48/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5253e-04 - val_loss: 2.7739e-04
# Epoch 49/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3907e-04 - val_loss: 2.6206e-04
# Epoch 50/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2044e-04 - val_loss: 2.5360e-04
# Epoch 51/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0452e-04 - val_loss: 2.3328e-04
# Epoch 52/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9014e-04 - val_loss: 2.2115e-04
# Epoch 53/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7790e-04 - val_loss: 2.0121e-04
# Epoch 54/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6634e-04 - val_loss: 1.9259e-04
# Epoch 55/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5016e-04 - val_loss: 1.7870e-04
# Epoch 56/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.4453e-04 - val_loss: 1.6984e-04
# Epoch 57/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.3578e-04 - val_loss: 1.6722e-04
# Epoch 58/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.2998e-04 - val_loss: 1.5567e-04
# Epoch 59/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.1997e-04 - val_loss: 1.5447e-04
# Epoch 60/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.1928e-04 - val_loss: 1.5579e-04
# Epoch 61/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.1682e-04 - val_loss: 1.4834e-04
# Epoch 62/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.1177e-04 - val_loss: 1.3688e-04
# Epoch 63/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.0400e-04 - val_loss: 1.3313e-04
# Epoch 64/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.0152e-04 - val_loss: 1.3126e-04
# Epoch 65/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.0328e-04 - val_loss: 1.4906e-04
# Epoch 66/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.0724e-04 - val_loss: 1.2379e-04
# Epoch 67/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 9.2537e-05 - val_loss: 1.2452e-04
# Epoch 68/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 8.9573e-05 - val_loss: 1.1568e-04
# Epoch 69/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 8.5838e-05 - val_loss: 1.1470e-04
# Epoch 70/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 8.6274e-05 - val_loss: 1.1178e-04
# Epoch 71/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 8.2690e-05 - val_loss: 1.1455e-04
# Epoch 72/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 8.2500e-05 - val_loss: 1.0870e-04
# Epoch 73/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 8.2788e-05 - val_loss: 1.0636e-04
# Epoch 74/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 8.4686e-05 - val_loss: 1.0407e-04
# Epoch 75/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 7.5657e-05 - val_loss: 1.0919e-04
# Epoch 76/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 7.9676e-05 - val_loss: 1.0843e-04
# Epoch 77/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 7.8412e-05 - val_loss: 9.5553e-05
# Epoch 78/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 7.4839e-05 - val_loss: 9.4771e-05
# Epoch 79/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 7.0877e-05 - val_loss: 9.9937e-05
# Epoch 80/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.8154e-05 - val_loss: 9.4512e-05
# Epoch 81/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.8244e-05 - val_loss: 1.0765e-04
# Epoch 82/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.8625e-05 - val_loss: 9.3967e-05
# Epoch 83/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.7824e-05 - val_loss: 9.9905e-05
# Epoch 84/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 7.4832e-05 - val_loss: 1.0320e-04
# Epoch 85/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.6000e-05 - val_loss: 9.7103e-05
# Epoch 86/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.2781e-05 - val_loss: 8.5888e-05
# Epoch 87/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.5538e-05 - val_loss: 8.8727e-05
# Epoch 88/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.7339e-05 - val_loss: 8.1742e-05
# Epoch 89/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.2285e-05 - val_loss: 7.8886e-05
# Epoch 90/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.2786e-05 - val_loss: 7.7841e-05
# Epoch 91/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.7523e-05 - val_loss: 7.8965e-05
# Epoch 92/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 6.0670e-05 - val_loss: 7.7302e-05
# Epoch 93/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.7966e-05 - val_loss: 7.8487e-05
# Epoch 94/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.7134e-05 - val_loss: 7.2113e-05
# Epoch 95/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.5083e-05 - val_loss: 7.5957e-05
# Epoch 96/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.6259e-05 - val_loss: 7.6351e-05
# Epoch 97/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.4402e-05 - val_loss: 7.0575e-05
# Epoch 98/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.6376e-05 - val_loss: 7.1640e-05
# Epoch 99/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.1707e-05 - val_loss: 7.6122e-05
# Epoch 100/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.2808e-05 - val_loss: 6.9846e-05
# Epoch 101/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.8550e-05 - val_loss: 6.8426e-05
# Epoch 102/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.3770e-05 - val_loss: 7.9421e-05
# Epoch 103/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.2103e-05 - val_loss: 7.1047e-05
# Epoch 104/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.9014e-05 - val_loss: 6.5834e-05
# Epoch 105/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.0472e-05 - val_loss: 7.5123e-05
# Epoch 106/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.7578e-05 - val_loss: 8.5089e-05
# Epoch 107/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.9601e-05 - val_loss: 6.7634e-05
# Epoch 108/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.4941e-05 - val_loss: 6.3273e-05
# Epoch 109/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.3642e-05 - val_loss: 6.3181e-05
# Epoch 110/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.3799e-05 - val_loss: 6.2366e-05
# Epoch 111/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.3210e-05 - val_loss: 6.3566e-05
# Epoch 112/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.1966e-05 - val_loss: 6.1032e-05
# Epoch 113/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.2363e-05 - val_loss: 7.2241e-05
# Epoch 114/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.6498e-05 - val_loss: 6.2699e-05
# Epoch 115/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.3671e-05 - val_loss: 7.1786e-05
# Epoch 116/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.3393e-05 - val_loss: 6.3677e-05
# Epoch 117/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.0396e-05 - val_loss: 6.4167e-05
# Epoch 118/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.8435e-05 - val_loss: 6.4222e-05
# Epoch 119/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.5644e-05 - val_loss: 6.9487e-05
# Epoch 120/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.4042e-05 - val_loss: 5.9731e-05
# Epoch 121/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.7393e-05 - val_loss: 1.0490e-04
# Epoch 122/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.8358e-05 - val_loss: 5.6649e-05
# Epoch 123/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.2820e-05 - val_loss: 5.6619e-05
# Epoch 124/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.6665e-05 - val_loss: 5.5680e-05
# Epoch 125/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.7486e-05 - val_loss: 6.0258e-05
# Epoch 126/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.9913e-05 - val_loss: 6.6244e-05
# Epoch 127/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.0075e-05 - val_loss: 5.7479e-05
# Epoch 128/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.1209e-05 - val_loss: 7.2659e-05
# Epoch 129/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.9262e-05 - val_loss: 7.3094e-05
# Epoch 130/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.1658e-05 - val_loss: 5.3535e-05
# Epoch 131/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.5941e-05 - val_loss: 5.3851e-05
# Epoch 132/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.7250e-05 - val_loss: 6.3012e-05
# Epoch 133/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.5586e-05 - val_loss: 5.7631e-05
# Epoch 134/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.5386e-05 - val_loss: 6.1409e-05
# Epoch 135/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.6750e-05 - val_loss: 6.0144e-05
# Epoch 136/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.5992e-05 - val_loss: 5.1689e-05
# Epoch 137/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.9080e-05 - val_loss: 5.3508e-05
# Epoch 138/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.4278e-05 - val_loss: 6.8625e-05
# Epoch 139/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.6101e-05 - val_loss: 6.6140e-05
# Epoch 140/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.6481e-05 - val_loss: 5.1755e-05
# Epoch 141/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.6275e-05 - val_loss: 5.0932e-05
# Epoch 142/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.3111e-05 - val_loss: 5.7030e-05
# Epoch 143/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.4364e-05 - val_loss: 5.2332e-05
# Epoch 144/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.6064e-05 - val_loss: 4.8933e-05
# Epoch 145/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.4825e-05 - val_loss: 5.1527e-05
# Epoch 146/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.4378e-05 - val_loss: 6.6472e-05
# Epoch 147/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.2763e-05 - val_loss: 5.8275e-05
# Epoch 148/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.5496e-05 - val_loss: 5.3147e-05
# Epoch 149/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.6555e-05 - val_loss: 5.9356e-05
# Epoch 150/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.2838e-05 - val_loss: 4.7394e-05
# Epoch 151/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.4529e-05 - val_loss: 8.3105e-05
# Epoch 152/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.6195e-05 - val_loss: 5.7479e-05
# Epoch 153/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.0022e-05 - val_loss: 5.3740e-05
# Epoch 154/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.2518e-05 - val_loss: 5.7268e-05
# Epoch 155/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.2552e-05 - val_loss: 4.7661e-05
# Epoch 156/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.5136e-05 - val_loss: 4.6221e-05
# Epoch 157/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.2787e-05 - val_loss: 4.7351e-05
# Epoch 158/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.9729e-05 - val_loss: 4.9489e-05
# Epoch 159/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.5903e-05 - val_loss: 4.6884e-05
# Epoch 160/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.9758e-05 - val_loss: 5.5847e-05
# Epoch 161/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.3060e-05 - val_loss: 5.0671e-05
# Epoch 162/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.1394e-05 - val_loss: 4.7549e-05
# Epoch 163/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.7735e-05 - val_loss: 4.8532e-05
# Epoch 164/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.9240e-05 - val_loss: 4.6561e-05
# Epoch 165/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.2814e-05 - val_loss: 5.3413e-05
# Epoch 166/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.8890e-05 - val_loss: 6.2645e-05
# Epoch 167/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.3427e-05 - val_loss: 4.1827e-05
# Epoch 168/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.8354e-05 - val_loss: 4.5864e-05
# Epoch 169/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.3562e-05 - val_loss: 4.2901e-05
# Epoch 170/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.9334e-05 - val_loss: 4.5207e-05
# Epoch 171/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.5640e-05 - val_loss: 4.3934e-05
# Epoch 172/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.3060e-05 - val_loss: 6.6060e-05
# Epoch 173/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.1510e-05 - val_loss: 4.0998e-05
# Epoch 174/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.8649e-05 - val_loss: 5.3672e-05
# Epoch 175/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.7906e-05 - val_loss: 4.0480e-05
# Epoch 176/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.3713e-05 - val_loss: 4.5729e-05
# Epoch 177/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.9146e-05 - val_loss: 4.6799e-05
# Epoch 178/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.7374e-05 - val_loss: 4.1720e-05
# Epoch 179/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.1381e-05 - val_loss: 5.1678e-05
# Epoch 180/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.9257e-05 - val_loss: 4.3950e-05
# Epoch 181/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.9615e-05 - val_loss: 5.0125e-05
# Epoch 182/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.2650e-05 - val_loss: 5.2704e-05
# Epoch 183/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.4989e-05 - val_loss: 3.9599e-05
# Epoch 184/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.5593e-05 - val_loss: 3.8656e-05
# Epoch 185/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.1349e-05 - val_loss: 4.1308e-05
# Epoch 186/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6470e-05 - val_loss: 4.1019e-05
# Epoch 187/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.6929e-05 - val_loss: 3.8450e-05
# Epoch 188/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5970e-05 - val_loss: 4.4633e-05
# Epoch 189/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.3106e-05 - val_loss: 4.0535e-05
# Epoch 190/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.6694e-05 - val_loss: 4.6552e-05
# Epoch 191/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.1578e-05 - val_loss: 4.1161e-05
# Epoch 192/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.3695e-05 - val_loss: 4.0701e-05
# Epoch 193/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.9993e-05 - val_loss: 4.4950e-05
# Epoch 194/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.8132e-05 - val_loss: 4.3638e-05
# Epoch 195/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5785e-05 - val_loss: 6.4224e-05
# Epoch 196/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.1112e-05 - val_loss: 3.6724e-05
# Epoch 197/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.9610e-05 - val_loss: 3.7136e-05
# Epoch 198/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.1173e-05 - val_loss: 4.8775e-05
# Epoch 199/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.5086e-05 - val_loss: 3.7664e-05
# Epoch 200/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6802e-05 - val_loss: 5.6448e-05
# Epoch 201/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 4.1294e-05 - val_loss: 4.1557e-05
# Epoch 202/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.2338e-05 - val_loss: 3.6504e-05
# Epoch 203/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.8937e-05 - val_loss: 3.9897e-05
# Epoch 204/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.5872e-05 - val_loss: 4.2990e-05
# Epoch 205/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6425e-05 - val_loss: 3.9798e-05
# Epoch 206/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5772e-05 - val_loss: 3.7213e-05
# Epoch 207/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.8206e-05 - val_loss: 4.8145e-05
# Epoch 208/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.1555e-05 - val_loss: 4.2992e-05
# Epoch 209/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.8064e-05 - val_loss: 5.6863e-05
# Epoch 210/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7709e-05 - val_loss: 5.0203e-05
# Epoch 211/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3902e-05 - val_loss: 3.9753e-05
# Epoch 212/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2650e-05 - val_loss: 3.8440e-05
# Epoch 213/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.8064e-05 - val_loss: 3.7366e-05
# Epoch 214/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.4995e-05 - val_loss: 3.8524e-05
# Epoch 215/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.4912e-05 - val_loss: 3.4210e-05
# Epoch 216/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.8715e-05 - val_loss: 4.1036e-05
# Epoch 217/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.3411e-05 - val_loss: 7.9765e-05
# Epoch 218/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.6105e-05 - val_loss: 3.3619e-05
# Epoch 219/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6653e-05 - val_loss: 3.5664e-05
# Epoch 220/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.0395e-05 - val_loss: 8.3254e-05
# Epoch 221/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7481e-05 - val_loss: 4.0777e-05
# Epoch 222/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.3216e-05 - val_loss: 3.6406e-05
# Epoch 223/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.4705e-05 - val_loss: 3.6852e-05
# Epoch 224/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.3484e-05 - val_loss: 3.4719e-05
# Epoch 225/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.5662e-05 - val_loss: 5.7880e-05
# Epoch 226/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.8726e-05 - val_loss: 3.2729e-05
# Epoch 227/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5344e-05 - val_loss: 4.8138e-05
# Epoch 228/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.4872e-05 - val_loss: 4.2011e-05
# Epoch 229/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.4268e-05 - val_loss: 3.2889e-05
# Epoch 230/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5930e-05 - val_loss: 3.6308e-05
# Epoch 231/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.4489e-05 - val_loss: 3.8228e-05
# Epoch 232/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.1887e-05 - val_loss: 3.3176e-05
# Epoch 233/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3175e-05 - val_loss: 3.7439e-05
# Epoch 234/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.7774e-05 - val_loss: 6.6054e-05
# Epoch 235/1000
# 23/23 [==============================] - ETA: 0s - loss: 6.4540e-0 - 0s 3ms/step - loss: 3.4346e-05 - val_loss: 3.3214e-05
# Epoch 236/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.4450e-05 - val_loss: 3.6911e-05
# Epoch 237/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7880e-05 - val_loss: 3.4255e-05
# Epoch 238/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.5715e-05 - val_loss: 3.2412e-05
# Epoch 239/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3029e-05 - val_loss: 3.2268e-05
# Epoch 240/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6054e-05 - val_loss: 5.7828e-05
# Epoch 241/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.9267e-05 - val_loss: 6.5153e-05
# Epoch 242/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.6218e-05 - val_loss: 4.8344e-05
# Epoch 243/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.4052e-05 - val_loss: 3.1731e-05
# Epoch 244/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1060e-05 - val_loss: 4.0984e-05
# Epoch 245/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5498e-05 - val_loss: 3.4374e-05
# Epoch 246/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3713e-05 - val_loss: 4.0999e-05
# Epoch 247/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.3330e-05 - val_loss: 4.2975e-05
# Epoch 248/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.2156e-05 - val_loss: 5.8807e-05
# Epoch 249/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.3997e-05 - val_loss: 3.3376e-05
# Epoch 250/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.4668e-05 - val_loss: 8.3499e-05
# Epoch 251/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.4542e-05 - val_loss: 4.9211e-05
# Epoch 252/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.1160e-05 - val_loss: 3.6639e-05
# Epoch 253/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.1007e-05 - val_loss: 6.3146e-05
# Epoch 254/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6143e-05 - val_loss: 3.1216e-05
# Epoch 255/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5984e-05 - val_loss: 3.1926e-05
# Epoch 256/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0279e-05 - val_loss: 3.4691e-05
# Epoch 257/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5608e-05 - val_loss: 3.6307e-05
# Epoch 258/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7523e-05 - val_loss: 3.5778e-05
# Epoch 259/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9381e-05 - val_loss: 3.2107e-05
# Epoch 260/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2270e-05 - val_loss: 3.4439e-05
# Epoch 261/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2735e-05 - val_loss: 5.0842e-05
# Epoch 262/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 3.2168e-05 - val_loss: 3.1433e-05
# Epoch 263/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.3384e-05 - val_loss: 4.4090e-05
# Epoch 264/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 1.9738e-05 - val_loss: 3.0891e-05
# Epoch 265/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.8297e-05 - val_loss: 6.7431e-05
# Epoch 266/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.1654e-05 - val_loss: 4.2084e-05
# Epoch 267/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.0410e-05 - val_loss: 4.1109e-05
# Epoch 268/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6702e-05 - val_loss: 3.4313e-05
# Epoch 269/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.3344e-05 - val_loss: 3.4622e-05
# Epoch 270/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.6485e-05 - val_loss: 3.4654e-05
# Epoch 271/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.9361e-05 - val_loss: 3.4934e-05
# Epoch 272/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3108e-05 - val_loss: 2.8543e-05
# Epoch 273/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1487e-05 - val_loss: 3.0957e-05
# Epoch 274/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0554e-05 - val_loss: 4.4188e-05
# Epoch 275/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1558e-05 - val_loss: 2.9063e-05
# Epoch 276/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0009e-05 - val_loss: 4.2350e-05
# Epoch 277/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7572e-05 - val_loss: 3.2833e-05
# Epoch 278/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2281e-05 - val_loss: 3.2543e-05
# Epoch 279/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6225e-05 - val_loss: 6.8358e-05
# Epoch 280/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.9651e-05 - val_loss: 3.0434e-05
# Epoch 281/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0624e-05 - val_loss: 3.0582e-05
# Epoch 282/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3545e-05 - val_loss: 3.6880e-05
# Epoch 283/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.4295e-05 - val_loss: 5.4876e-05
# Epoch 284/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6013e-05 - val_loss: 2.8559e-05
# Epoch 285/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1846e-05 - val_loss: 3.0258e-05
# Epoch 286/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.1328e-05 - val_loss: 2.9193e-05
# Epoch 287/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9652e-05 - val_loss: 2.8403e-05
# Epoch 288/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8723e-05 - val_loss: 2.7120e-05
# Epoch 289/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1219e-05 - val_loss: 5.6689e-05
# Epoch 290/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.8519e-05 - val_loss: 3.4324e-05
# Epoch 291/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 5.5368e-05 - val_loss: 7.4170e-05
# Epoch 292/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.6980e-05 - val_loss: 6.4026e-05
# Epoch 293/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7732e-05 - val_loss: 3.7577e-05
# Epoch 294/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.3416e-05 - val_loss: 2.8229e-05
# Epoch 295/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7841e-05 - val_loss: 2.5212e-05
# Epoch 296/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0313e-05 - val_loss: 2.9910e-05
# Epoch 297/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2088e-05 - val_loss: 3.1668e-05
# Epoch 298/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3052e-05 - val_loss: 2.8344e-05
# Epoch 299/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0047e-05 - val_loss: 3.8447e-05
# Epoch 300/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7293e-05 - val_loss: 3.0121e-05
# Epoch 301/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0262e-05 - val_loss: 3.1315e-05
# Epoch 302/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3416e-05 - val_loss: 3.1895e-05
# Epoch 303/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2746e-05 - val_loss: 2.7035e-05
# Epoch 304/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9364e-05 - val_loss: 2.7415e-05
# Epoch 305/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.4937e-05 - val_loss: 5.2284e-05
# Epoch 306/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.1545e-05 - val_loss: 3.9969e-05
# Epoch 307/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6858e-05 - val_loss: 2.9298e-05
# Epoch 308/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9765e-05 - val_loss: 2.4969e-05
# Epoch 309/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5283e-05 - val_loss: 2.9399e-05
# Epoch 310/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1836e-05 - val_loss: 3.6604e-05
# Epoch 311/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8936e-05 - val_loss: 2.9478e-05
# Epoch 312/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1693e-05 - val_loss: 3.0179e-05
# Epoch 313/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9364e-05 - val_loss: 2.7341e-05
# Epoch 314/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0957e-05 - val_loss: 3.1489e-05
# Epoch 315/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8878e-05 - val_loss: 4.9604e-05
# Epoch 316/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.5734e-05 - val_loss: 3.1310e-05
# Epoch 317/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0979e-05 - val_loss: 3.9123e-05
# Epoch 318/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6677e-05 - val_loss: 2.5427e-05
# Epoch 319/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0826e-05 - val_loss: 3.7723e-05
# Epoch 320/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0599e-05 - val_loss: 2.3960e-05
# Epoch 321/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1338e-05 - val_loss: 3.2389e-05
# Epoch 322/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9157e-05 - val_loss: 3.0993e-05
# Epoch 323/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.4451e-05 - val_loss: 3.2520e-05
# Epoch 324/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1415e-05 - val_loss: 3.0542e-05
# Epoch 325/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5030e-05 - val_loss: 4.3820e-05
# Epoch 326/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5142e-05 - val_loss: 3.2929e-05
# Epoch 327/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0588e-05 - val_loss: 2.6559e-05
# Epoch 328/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5170e-05 - val_loss: 2.8012e-05
# Epoch 329/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3228e-05 - val_loss: 2.3792e-05
# Epoch 330/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3771e-05 - val_loss: 4.8630e-05
# Epoch 331/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6003e-05 - val_loss: 2.7997e-05
# Epoch 332/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6262e-05 - val_loss: 3.1150e-05
# Epoch 333/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0965e-05 - val_loss: 2.6631e-05
# Epoch 334/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9402e-05 - val_loss: 2.8904e-05
# Epoch 335/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0074e-05 - val_loss: 3.6703e-05
# Epoch 336/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.9668e-05 - val_loss: 7.3023e-05
# Epoch 337/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.3647e-05 - val_loss: 2.9403e-05
# Epoch 338/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7437e-05 - val_loss: 2.5172e-05
# Epoch 339/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1634e-05 - val_loss: 2.3419e-05
# Epoch 340/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9799e-05 - val_loss: 2.3327e-05
# Epoch 341/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2511e-05 - val_loss: 2.3388e-05
# Epoch 342/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0903e-05 - val_loss: 2.3848e-05
# Epoch 343/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1073e-05 - val_loss: 3.4910e-05
# Epoch 344/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.2695e-05 - val_loss: 2.3551e-05
# Epoch 345/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1185e-05 - val_loss: 2.5248e-05
# Epoch 346/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6157e-05 - val_loss: 2.3413e-05
# Epoch 347/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6878e-05 - val_loss: 2.5709e-05
# Epoch 348/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2389e-05 - val_loss: 2.8714e-05
# Epoch 349/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0723e-05 - val_loss: 2.9190e-05
# Epoch 350/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3175e-05 - val_loss: 6.0288e-05
# Epoch 351/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.8964e-05 - val_loss: 3.8204e-05
# Epoch 352/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5938e-05 - val_loss: 3.4471e-05
# Epoch 353/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.4821e-05 - val_loss: 4.2176e-05
# Epoch 354/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3847e-05 - val_loss: 2.7973e-05
# Epoch 355/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0907e-05 - val_loss: 2.6206e-05
# Epoch 356/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.3149e-05 - val_loss: 3.0499e-05
# Epoch 357/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0538e-05 - val_loss: 2.6495e-05
# Epoch 358/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7430e-05 - val_loss: 2.2481e-05
# Epoch 359/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9546e-05 - val_loss: 2.6183e-05
# Epoch 360/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5263e-05 - val_loss: 2.4527e-05
# Epoch 361/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1895e-05 - val_loss: 3.0258e-05
# Epoch 362/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7942e-05 - val_loss: 2.5298e-05
# Epoch 363/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6251e-05 - val_loss: 2.2750e-05
# Epoch 364/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8598e-05 - val_loss: 2.4133e-05
# Epoch 365/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8103e-05 - val_loss: 2.0761e-05
# Epoch 366/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.4441e-05 - val_loss: 3.1921e-05
# Epoch 367/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6988e-05 - val_loss: 2.5989e-05
# Epoch 368/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3886e-05 - val_loss: 2.7158e-05
# Epoch 369/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2796e-05 - val_loss: 2.7022e-05
# Epoch 370/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5382e-05 - val_loss: 8.6466e-05
# Epoch 371/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.9247e-05 - val_loss: 3.1448e-05
# Epoch 372/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3099e-05 - val_loss: 2.4708e-05
# Epoch 373/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.4950e-05 - val_loss: 8.7011e-05
# Epoch 374/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.0859e-05 - val_loss: 4.8410e-05
# Epoch 375/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.9733e-05 - val_loss: 6.6255e-05
# Epoch 376/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.3021e-05 - val_loss: 7.0322e-05
# Epoch 377/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.8242e-05 - val_loss: 2.3636e-05
# Epoch 378/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7563e-05 - val_loss: 2.5412e-05
# Epoch 379/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7479e-05 - val_loss: 2.1165e-05
# Epoch 380/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6954e-05 - val_loss: 2.5492e-05
# Epoch 381/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6379e-05 - val_loss: 2.7128e-05
# Epoch 382/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8855e-05 - val_loss: 2.0375e-05
# Epoch 383/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5653e-05 - val_loss: 2.0144e-05
# Epoch 384/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8645e-05 - val_loss: 2.6152e-05
# Epoch 385/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1263e-05 - val_loss: 2.3611e-05
# Epoch 386/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.4206e-05 - val_loss: 4.3565e-05
# Epoch 387/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.3302e-05 - val_loss: 2.7078e-05
# Epoch 388/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1052e-05 - val_loss: 3.3234e-05
# Epoch 389/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9636e-05 - val_loss: 2.4099e-05
# Epoch 390/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.4628e-05 - val_loss: 2.2637e-05
# Epoch 391/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7682e-05 - val_loss: 2.1818e-05
# Epoch 392/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7686e-05 - val_loss: 2.0041e-05
# Epoch 393/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5698e-05 - val_loss: 2.4836e-05
# Epoch 394/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0486e-05 - val_loss: 4.5200e-05
# Epoch 395/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3536e-05 - val_loss: 3.0160e-05
# Epoch 396/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.4797e-05 - val_loss: 2.7375e-05
# Epoch 397/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6047e-05 - val_loss: 3.2135e-05
# Epoch 398/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2650e-05 - val_loss: 2.1514e-05
# Epoch 399/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6481e-05 - val_loss: 2.4234e-05
# Epoch 400/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9342e-05 - val_loss: 2.5181e-05
# Epoch 401/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7388e-05 - val_loss: 3.9429e-05
# Epoch 402/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5849e-05 - val_loss: 4.6573e-05
# Epoch 403/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7299e-05 - val_loss: 2.2554e-05
# Epoch 404/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5344e-05 - val_loss: 2.1284e-05
# Epoch 405/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5719e-05 - val_loss: 2.8400e-05
# Epoch 406/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2519e-05 - val_loss: 4.1265e-05
# Epoch 407/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0095e-05 - val_loss: 2.8918e-05
# Epoch 408/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7681e-05 - val_loss: 2.4463e-05
# Epoch 409/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0529e-05 - val_loss: 2.1170e-05
# Epoch 410/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1309e-05 - val_loss: 3.1747e-05
# Epoch 411/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.9047e-05 - val_loss: 3.6058e-05
# Epoch 412/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2413e-05 - val_loss: 2.2440e-05
# Epoch 413/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6175e-05 - val_loss: 2.5586e-05
# Epoch 414/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3993e-05 - val_loss: 2.2871e-05
# Epoch 415/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.7587e-05 - val_loss: 2.5784e-05
# Epoch 416/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.8619e-05 - val_loss: 2.1559e-05
# Epoch 417/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1110e-05 - val_loss: 2.8801e-05
# Epoch 418/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9750e-05 - val_loss: 2.4297e-05
# Epoch 419/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0993e-05 - val_loss: 2.1372e-05
# Epoch 420/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.9146e-05 - val_loss: 4.6354e-05
# Epoch 421/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0000e-05 - val_loss: 3.7049e-05
# Epoch 422/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9817e-05 - val_loss: 2.2307e-05
# Epoch 423/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6115e-05 - val_loss: 2.3611e-05
# Epoch 424/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3953e-05 - val_loss: 2.8768e-05
# Epoch 425/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6691e-05 - val_loss: 4.2126e-05
# Epoch 426/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1503e-05 - val_loss: 2.2705e-05
# Epoch 427/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6437e-05 - val_loss: 1.9862e-05
# Epoch 428/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5351e-05 - val_loss: 2.1025e-05
# Epoch 429/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5058e-05 - val_loss: 2.3351e-05
# Epoch 430/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1782e-05 - val_loss: 3.3509e-05
# Epoch 431/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5494e-05 - val_loss: 2.4091e-05
# Epoch 432/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1557e-05 - val_loss: 2.1628e-05
# Epoch 433/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.4243e-05 - val_loss: 2.2149e-05
# Epoch 434/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5328e-05 - val_loss: 3.2381e-05
# Epoch 435/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0734e-05 - val_loss: 2.3094e-05
# Epoch 436/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6521e-05 - val_loss: 2.4387e-05
# Epoch 437/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5489e-05 - val_loss: 2.5800e-05
# Epoch 438/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2810e-05 - val_loss: 3.8142e-05
# Epoch 439/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1535e-05 - val_loss: 2.1559e-05
# Epoch 440/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1005e-05 - val_loss: 2.6474e-05
# Epoch 441/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7373e-05 - val_loss: 2.4231e-05
# Epoch 442/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6462e-05 - val_loss: 2.0320e-05
# Epoch 443/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5702e-05 - val_loss: 2.0253e-05
# Epoch 444/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.4557e-05 - val_loss: 2.0635e-05
# Epoch 445/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6179e-05 - val_loss: 2.6982e-05
# Epoch 446/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1253e-05 - val_loss: 2.4919e-05
# Epoch 447/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0385e-05 - val_loss: 2.9489e-05
# Epoch 448/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8156e-05 - val_loss: 2.4739e-05
# Epoch 449/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 1.7024e-05 - val_loss: 2.1094e-05
# Epoch 450/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5134e-05 - val_loss: 2.0204e-05
# Epoch 451/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.4226e-05 - val_loss: 3.2771e-05
# Epoch 452/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8050e-05 - val_loss: 3.1179e-05
# Epoch 453/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2042e-05 - val_loss: 2.5972e-05
# Epoch 454/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8394e-05 - val_loss: 2.3973e-05
# Epoch 455/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6018e-05 - val_loss: 2.0060e-05
# Epoch 456/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.4858e-05 - val_loss: 2.1844e-05
# Epoch 457/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5323e-05 - val_loss: 3.6418e-05
# Epoch 458/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7879e-05 - val_loss: 3.0211e-05
# Epoch 459/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7667e-05 - val_loss: 3.1321e-05
# Epoch 460/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 1.5110e-05 - val_loss: 2.6942e-05
# Epoch 461/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9108e-05 - val_loss: 5.5256e-05
# Epoch 462/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.4052e-05 - val_loss: 6.5394e-05
# Epoch 463/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.3344e-05 - val_loss: 3.0630e-05
# Epoch 464/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0505e-05 - val_loss: 2.8935e-05
# Epoch 465/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9552e-05 - val_loss: 2.6768e-05
# Epoch 466/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6554e-05 - val_loss: 2.1890e-05
# Epoch 467/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 2.1442e-05 - val_loss: 2.9752e-05
# Epoch 468/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9885e-05 - val_loss: 2.2916e-05
# Epoch 469/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5401e-05 - val_loss: 2.0924e-05
# Epoch 470/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6522e-05 - val_loss: 1.9796e-05
# Epoch 471/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5570e-05 - val_loss: 2.0998e-05
# Epoch 472/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1605e-05 - val_loss: 2.2750e-05
# Epoch 473/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5814e-05 - val_loss: 2.1111e-05
# Epoch 474/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5838e-05 - val_loss: 2.0010e-05
# Epoch 475/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0409e-05 - val_loss: 2.3146e-05
# Epoch 476/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6513e-05 - val_loss: 2.4323e-05
# Epoch 477/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7546e-05 - val_loss: 2.2420e-05
# Epoch 478/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.4239e-05 - val_loss: 2.1060e-05
# Epoch 479/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1488e-05 - val_loss: 7.2773e-05
# Epoch 480/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 4.0528e-05 - val_loss: 5.3454e-05
# Epoch 481/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5293e-05 - val_loss: 3.0420e-05
# Epoch 482/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7976e-05 - val_loss: 2.3863e-05
# Epoch 483/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.0607e-05 - val_loss: 2.8088e-05
# Epoch 484/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5545e-05 - val_loss: 2.3293e-05
# Epoch 485/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6876e-05 - val_loss: 5.6215e-05
# Epoch 486/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6255e-05 - val_loss: 1.9462e-05
# Epoch 487/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8857e-05 - val_loss: 2.8027e-05
# Epoch 488/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7593e-05 - val_loss: 4.2620e-05
# Epoch 489/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 1.8157e-05 - val_loss: 2.0289e-05
# Epoch 490/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1812e-05 - val_loss: 2.7794e-05
# Epoch 491/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8046e-05 - val_loss: 2.1730e-05
# Epoch 492/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.4153e-05 - val_loss: 2.3611e-05
# Epoch 493/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2973e-05 - val_loss: 1.9950e-05
# Epoch 494/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7236e-05 - val_loss: 3.4063e-05
# Epoch 495/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5562e-05 - val_loss: 1.9692e-05
# Epoch 496/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5009e-05 - val_loss: 2.4752e-05
# Epoch 497/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6649e-05 - val_loss: 2.8452e-05
# Epoch 498/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7860e-05 - val_loss: 2.2088e-05
# Epoch 499/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8360e-05 - val_loss: 2.5334e-05
# Epoch 500/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 1.6621e-05 - val_loss: 3.1352e-05
# Epoch 501/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5631e-05 - val_loss: 2.0741e-05
# Epoch 502/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7410e-05 - val_loss: 2.3023e-05
# Epoch 503/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.1590e-05 - val_loss: 5.3523e-05
# Epoch 504/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.5713e-05 - val_loss: 5.8944e-05
# Epoch 505/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.1451e-05 - val_loss: 2.7481e-05
# Epoch 506/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9161e-05 - val_loss: 2.2723e-05
# Epoch 507/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5416e-05 - val_loss: 2.0765e-05
# Epoch 508/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8986e-05 - val_loss: 2.3642e-05
# Epoch 509/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 1.6495e-05 - val_loss: 2.3084e-05
# Epoch 510/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7562e-05 - val_loss: 4.4218e-05
# Epoch 511/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.6464e-05 - val_loss: 2.1293e-05
# Epoch 512/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7914e-05 - val_loss: 2.2573e-05
# Epoch 513/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9285e-05 - val_loss: 2.9417e-05
# Epoch 514/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2105e-05 - val_loss: 2.0246e-05
# Epoch 515/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7589e-05 - val_loss: 2.7915e-05
# Epoch 516/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.9451e-05 - val_loss: 2.1991e-05
# Epoch 517/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7331e-05 - val_loss: 2.0418e-05
# Epoch 518/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7022e-05 - val_loss: 2.4199e-05
# Epoch 519/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6277e-05 - val_loss: 2.0247e-05
# Epoch 520/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7368e-05 - val_loss: 2.1051e-05
# Epoch 521/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0524e-05 - val_loss: 2.5019e-05
# Epoch 522/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6959e-05 - val_loss: 2.2275e-05
# Epoch 523/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5031e-05 - val_loss: 2.1943e-05
# Epoch 524/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9761e-05 - val_loss: 2.2550e-05
# Epoch 525/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9770e-05 - val_loss: 2.8228e-05
# Epoch 526/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9399e-05 - val_loss: 4.4674e-05
# Epoch 527/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6807e-05 - val_loss: 3.8011e-05
# Epoch 528/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7574e-05 - val_loss: 3.5492e-05
# Epoch 529/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 3.2275e-05 - val_loss: 3.5659e-05
# Epoch 530/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2461e-05 - val_loss: 3.0468e-05
# Epoch 531/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 1.6468e-05 - val_loss: 2.4811e-05
# Epoch 532/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.4086e-05 - val_loss: 2.0676e-05
# Epoch 533/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5236e-05 - val_loss: 2.2995e-05
# Epoch 534/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.9161e-05 - val_loss: 2.4021e-05
# Epoch 535/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1667e-05 - val_loss: 2.9615e-05
# Epoch 536/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8694e-05 - val_loss: 2.4204e-05
# Epoch 00536: early stopping

# %% [markdown]
# ### Plotting The Losses During Training

# %%
losses = pd.DataFrame(NNmodel.history.history)
plt.grid()
plt.yscale("log")
plt.plot(losses['loss'], label='train loss')
plt.plot(losses['val_loss'], label='validation loss')
plt.legend()
losses[['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Predicting On The Test Dataset

# %%
predictions = NNmodel.predict(X_test)

# %%
predictions = scalery.inverse_transform(predictions)
y_test = scalery.inverse_transform(y_test)

# %% [markdown]
# ### Mean Squared Error and Mean Absolute Error of the Prediction Results

# %%
mse_cl = mean_squared_error(y_test[:,0], predictions[:,0])
print(f"Mean Squared Error for Cl: {mse_cl}")
mae_cl = np.sum(np.absolute(y_test[:,0]- predictions[:,0]))/len(y_test)
print(f"Mean Absolute Error for Cl: {mae_cl}\n")
mse_cd = mean_squared_error(y_test[:,1], predictions[:,1])
print(f"Mean Squared Error for Cd: {mse_cd}")
mae_cd = np.sum(np.absolute(y_test[:,1]- predictions[:,1]))/len(y_test)
print(f"Mean Absolute Error for Cd: {mae_cd}\n")
mse_cp = mean_squared_error(y_test[:,2], predictions[:,2])
print(f"Mean Squared Error for Cp: {mse_cp}")
mae_cp = np.sum(np.absolute(y_test[:,2]- predictions[:,2]))/len(y_test)
print(f"Mean Absolute Error for Cp: {mae_cp}\n")
# Out:
# Mean Squared Error for Cl: 3.8047730270698265e-07
# Mean Absolute Error for Cl: 0.0004270057912779239
#
# Mean Squared Error for Cd: 2.5475835017476398e-09
# Mean Absolute Error for Cd: 3.5530470466071944e-05
#
# Mean Squared Error for Cp: 2.110745146884554e-05
# Mean Absolute Error for Cp: 0.0029849188412753008

# %% [markdown]
# ### Predictions vs Ground Truth Plots

# %%
###############################Cl
# Creating figure Cl
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.title("Cl Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cl')
plt.title('Cl vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cl')
plt.title('Cl vs AoA')
plt.legend()
plt.show()

##############################Cd
# Creating figure Cd
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.title("Cd Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.legend()
plt.show()

##############################Cp
# Creating figure Cp
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,2], color = "g", alpha=0.6, label='Ground Truth')
plt.title("Cp Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,2], color = "green", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,2], color = "green", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.legend()
plt.show()

# %% [markdown]
# ### Sampling Predictions

# %%
sample_number = 6
#alldata=len(predictions)
print("[Cl Cd Cp]")
for i in range (sample_number):
    print(f"Sample Data {i+1}: {y_test[i]}")
    print(f"Prediction {i+1}: {predictions[i]}")
    error = np.abs(y_test[i]-predictions[i])
    print(f"error: {error}\n--------------------------------------------------")
# Out:
# [Cl Cd Cp]
# Sample Data 1: [ 0.683542  0.011203 -0.686882]
# Prediction 1: [ 0.6832293   0.01125204 -0.68822783]
# error: [3.12672798e-04 4.90391122e-05 1.34583232e-03]
# --------------------------------------------------
# Sample Data 2: [ 0.73528   0.013844 -1.152869]
# Prediction 2: [ 0.7345702   0.01387483 -1.1483296 ]
# error: [7.09794788e-04 3.08297468e-05 4.53938441e-03]
# --------------------------------------------------
# Sample Data 3: [ 0.675539  0.01153  -0.624721]
# Prediction 3: [ 0.6751507   0.01155784 -0.6235412 ]
# error: [3.88307537e-04 2.78360856e-05 1.17982368e-03]
# --------------------------------------------------
# Sample Data 4: [ 0.652789  0.010931 -0.671232]
# Prediction 4: [ 0.65250486  0.01096999 -0.6750751 ]
# error: [2.84138645e-04 3.89917957e-05 3.84311377e-03]
# --------------------------------------------------
# Sample Data 5: [ 0.723796  0.014562 -1.201687]
# Prediction 5: [ 0.72349215  0.0145872  -1.2015113 ]
# error: [3.03854462e-04 2.52039720e-05 1.75736153e-04]
# --------------------------------------------------
# Sample Data 6: [ 0.729271  0.015041 -1.210357]
# Prediction 6: [ 0.7294322   0.01505169 -1.2102941 ]
# error: [1.61225227e-04 1.06927242e-05 6.28725357e-05]
# --------------------------------------------------
