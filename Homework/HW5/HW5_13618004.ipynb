# %%
import pandas as pd

# %%
data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
n_train = len(data)

# %%
data = data.append(test_data)

data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
y_train = data['Survived'][:n_train]

# %%
data = data.drop(["PassengerId", "Survived", "Name", "Ticket", "Fare", "Embarked"], axis = 1)

data
# Out:
#      Pclass     Sex   Age  SibSp  Parch Cabin
# 0         3    male  22.0      1      0   NaN
# 1         1  female  38.0      1      0   C85
# 2         3  female  26.0      0      0   NaN
# 3         1  female  35.0      1      0  C123
# 4         3    male  35.0      0      0   NaN
# ..      ...     ...   ...    ...    ...   ...
# 413       3    male   NaN      0      0   NaN
# 414       1  female  39.0      0      0  C105
# 415       3    male  38.5      0      0   NaN
# 416       3    male   NaN      0      0   NaN
# 417       3    male   NaN      1      1   NaN
#
# [1309 rows x 6 columns]

# %%
data = data.fillna({"Age": data["Age"].mean()})
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  1309 non-null   int64
#  1   Sex     1309 non-null   object
#  2   Age     1309 non-null   float64
#  3   SibSp   1309 non-null   int64
#  4   Parch   1309 non-null   int64
#  5   Cabin   295 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 71.6+ KB

# %%
data['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
data['Cabin'] = data['Cabin'].map(lambda x: str(x)[0])

data['Cabin'].unique()
# Out:
# array(['n', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
data = pd.get_dummies(data)

data
# Out:
#      Pclass        Age  SibSp  Parch  Sex_female  Sex_male  Cabin_A  Cabin_B  \
# 0         3  22.000000      1      0           0         1        0        0
# 1         1  38.000000      1      0           1         0        0        0
# 2         3  26.000000      0      0           1         0        0        0
# 3         1  35.000000      1      0           1         0        0        0
# 4         3  35.000000      0      0           0         1        0        0
# ..      ...        ...    ...    ...         ...       ...      ...      ...
# 413       3  29.881138      0      0           0         1        0        0
# 414       1  39.000000      0      0           1         0        0        0
# 415       3  38.500000      0      0           0         1        0        0
# 416       3  29.881138      0      0           0         1        0        0
# 417       3  29.881138      1      1           0         1        0        0
#
# ...

# %%
data = data.drop(["Cabin_n"], axis = 1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(data)
scaled_data = scaler.transform(data)
scaled_data = pd.DataFrame(scaled_data, columns = data.columns)

scaled_data
# Out:
#         Pclass       Age     SibSp     Parch  Sex_female  Sex_male   Cabin_A  \
# 0     0.841916 -0.611972  0.481288 -0.445000   -0.743497  0.743497 -0.130744
# 1    -1.546098  0.630431  0.481288 -0.445000    1.344995 -1.344995 -0.130744
# 2     0.841916 -0.301371 -0.479087 -0.445000    1.344995 -1.344995 -0.130744
# 3    -1.546098  0.397481  0.481288 -0.445000    1.344995 -1.344995 -0.130744
# 4     0.841916  0.397481 -0.479087 -0.445000   -0.743497  0.743497 -0.130744
# ...        ...       ...       ...       ...         ...       ...       ...
# 1304  0.841916  0.000000 -0.479087 -0.445000   -0.743497  0.743497 -0.130744
# 1305 -1.546098  0.708081 -0.479087 -0.445000    1.344995 -1.344995 -0.130744
# 1306  0.841916  0.669256 -0.479087 -0.445000   -0.743497  0.743497 -0.130744
# 1307  0.841916  0.000000 -0.479087 -0.445000   -0.743497  0.743497 -0.130744
# 1308  0.841916  0.000000  0.481288  0.710763   -0.743497  0.743497 -0.130744
#
# ...

# %%
X_train = scaled_data[:n_train]
X_test = scaled_data[n_train:]

# %%
from sklearn.svm import SVC

clf = SVC()
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
sample = X_train.iloc[3,:].tolist()

clf.predict([sample])
# Out:
# array([1.])

# %%
clf.score(X_train,y_train)
# Out:
# 0.8406285072951739
